# %% [markdown]
# <a href="https://colab.research.google.com/github/petr1987a/Collab/blob/main/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Studio Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 1135, done.
# remote: Counting objects: 100% (1135/1135), done.
# remote: Compressing objects: 100% (960/960), done.
# remote: Total 1135 (delta 178), reused 734 (delta 155), pack-reused 0 (from 0)
# Receiving objects: 100% (1135/1135), 32.62 MiB | 14.34 MiB/s, done.
# Resolving deltas: 100% (178/178), done.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#                  upgrading npm...
#   node           v20.19.0 | npm 11.12.1
#                  installing bun...
#                  bun installed (1.3.12)
#                  building frontend...
#                  using bun for package install (faster)
#   frontend       built
#                  Colab detected, installing Studio backend dependencies...
#   python         backend deps installed into system Python
#                  continuing to llama.cpp install for GGUF inference support
#   deps           [====================] 14/14  ROCm torch (final)
#   deps           installed
#   transformers   5.3.0 pre-installed
#   transformers   5.5.0 pre-installed
#                  installing prebuilt llama.cpp...
#   llama.cpp      prebuilt installed and validated
#                  installed release: unslothai/llama.cpp@b8811
#
#   ────────────────────────────────────────────────────
#   Unsloth Studio Setup Complete
#   ────────────────────────────────────────────────────
#                  from colab import start
#                  start()

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys, time
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start
start()
# Out:
# 2026-04-19 15:35:31 [info     ] 🦥 Starting Unsloth Studio...
# 2026-04-19 15:35:31 [info     ]    Loading backend...
# 2026-04-19 15:35:31 [info     ]    Starting server...
# INFO:     Started server process [8977]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8888 (Press CTRL+C to quit)
# Hardware detected: CUDA -- Tesla T4
#
# ============================================================
# DEFAULT ADMIN ACCOUNT CREATED
#     username: unsloth
#     password saved to: /root/.unsloth/studio/auth/.bootstrap_password
#     Open the Studio UI to sign in and change it.
# ============================================================
#
# {"timestamp": "2026-04-19T15:35:38.472476Z", "level": "info", "event": "Pre-caching helper GGUF: unsloth/gemma-4-E2B-it-GGUF/gemma-4-E2B-it-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-04-19T15:35:40.293597Z", "level": "info", "event": "   Server started!"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 26px; font-weight: 800;
#                    display: flex; align-items: center; gap: 12px;">
#             <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#                  height="48" style="display:block;">
#             Unsloth Studio is Ready!
#         </h2>
#         <a href="http://localhost:8888" target="_blank"
#            style="display: inline-flex; align-items: center; gap: 10px; padding: 14px 28px;
#                   background: #000000; color: white; text-decoration: none; border-radius: 8px;
#                   font-weight: 800; font-size: 16px;">
#             <svg xmlns="http://www.w3.org/2000/svg" width="18" height="18" viewBox="0 0 24 24" fill="white"><polygon points="5,3 19,12 5,21"/></svg>
#             Open Unsloth Studio
#         </a>
#         <p style="color: #333333; margin: 12px 0 0 0; font-size: 14px; font-weight: bold;">
#             If the link doesn't work, you can scroll down to view the UI generated directly in Colab.
#         </p>
#         <p style="color: #333333; margin: 16px 0 0 0; font-size: 13px; font-family: monospace; font-weight: bold;">
#             http://localhost:8888
#         </p>
#     </div>

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
for _ in range(10000): time.sleep(300), print("=", end = "")
# Out:
# {"timestamp": "2026-04-19T15:35:50.350440Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 7.58}
# {"timestamp": "2026-04-19T15:35:54.010319Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 1.01}
# {"timestamp": "2026-04-19T15:35:54.473606Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 74.54}
# {"timestamp": "2026-04-19T15:35:54.863575Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.53}
# {"timestamp": "2026-04-19T15:35:55.739149Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.79}
# {"timestamp": "2026-04-19T15:35:57.818981Z", "level": "info", "event": "Helper GGUF cached: 1 file(s)"}
# {"timestamp": "2026-04-19T15:36:50.287278Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 74.36}
# {"timestamp": "2026-04-19T15:36:50.852936Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/change-password", "status_code": 200, "process_time_ms": 153.62}
# {"timestamp": "2026-04-19T15:36:51.260835Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.49}
# {"timestamp": "2026-04-19T15:36:51.646588Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.44}
# {"timestamp": "2026-04-19T15:36:51.654111Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.21}
# {"timestamp": "2026-04-19T15:36:51.660907Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.15}
# {"timestamp": "2026-04-19T15:36:51.667964Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.22}
# {"timestamp": "2026-04-19T15:36:52.100091Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-04-19T15:36:52.601967Z", "level": "info", "event": "Top GGUF models: ['unsloth/gemma-4-26B-A4B-it-GGUF', 'unsloth/gemma-4-31B-it-GGUF', 'unsloth/gemma-4-E4B-it-GGUF', 'unsloth/Qwen3.5-35B-A3B-GGUF', 'unsloth/Qwen3.5-9B-GGUF', 'unsloth/gemma-4-E2B-it-GGUF', 'unsloth/Qwen3.6-35B-A3B-GGUF', 'unsloth/Qwen3.5-27B-GGUF', 'unsloth/Qwen3.5-4B-GGUF', 'unsloth/Qwen3.5-122B-A10B-GGUF', 'unsloth/Qwen3.5-2B-GGUF', 'unsloth/Qwen3.5-0.8B-GGUF', 'unsloth/LTX-2.3-GGUF', 'unsloth/gpt-oss-20b-GGUF', 'unsloth/Qwen3-Coder-Next-GGUF', 'unsloth/gpt-oss-120b-GGUF', 'unsloth/Qwen3-Coder-30B-A3B-Instruct-GGUF', 'unsloth/gemma-3-12b-it-GGUF', 'unsloth/MiniMax-M2.7-GGUF', 'unsloth/GLM-4.7-Flash-GGUF', 'unsloth/Qwen-Image-Edit-2511-GGUF', 'unsloth/Nemotron-3-Nano-30B-A3B-GGUF', 'unsloth/gemma-3-27b-it-GGUF', 'unsloth/DeepSeek-R1-Distill-Qwen-14B-GGUF', 'unsloth/MiniMax-M2.5-GGUF', 'unsloth/Qwen3.5-397B-A17B-GGUF', 'unsloth/DeepSeek-R1-Distill-Qwen-1.5B-GGUF', 'unsloth/Kimi-K2.5-GGUF', 'unsloth/gemma-3-4b-it-GGUF', 'unsloth/Qwen2.5-VL-7B-Instruct-GGUF', 'unsloth/Qwen3-VL-4B-Instruct-GGUF', 'unsloth/FLUX.2-klein-9B-GGUF', 'unsloth/Qwen3-0.6B-GGUF', 'unsloth/Qwen3-4B-GGUF', 'unsloth/NVIDIA-Nemotron-3-Super-120B-A12B-GGUF', 'unsloth/gemma-3-270m-it-GGUF']"}
# {"timestamp": "2026-04-19T15:36:52.602821Z", "level": "info", "event": "Top hub models: ['unsloth/Llama-3.1-8B-Instruct', 'unsloth/Mistral-Small-3.2-24B-Instruct-2506-bnb-4bit', 'unsloth/GLM-4.7-Flash', 'unsloth/mistral-7b-v0.3-bnb-4bit', 'unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit', 'unsloth/Qwen3-0.6B', 'unsloth/Qwen2.5-7B-Instruct', 'unsloth/Qwen3.5-9B', 'unsloth/gemma-4-31B-it-unsloth-bnb-4bit', 'unsloth/Qwen2.5-7B-Instruct-bnb-4bit', 'unsloth/gpt-oss-20b-unsloth-bnb-4bit', 'unsloth/Llama-3.2-3B-Instruct', 'unsloth/gpt-oss-120b-BF16', 'unsloth/Meta-Llama-3.1-8B-Instruct', 'unsloth/Qwen3.5-4B', 'unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit', 'unsloth/gemma-4-E4B-it', 'unsloth/Qwen3-0.6B-unsloth-bnb-4bit', 'unsloth/Qwen3-14B-unsloth-bnb-4bit', 'unsloth/Qwen2.5-3B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3.5-2B', 'unsloth/Llama-3.2-1B-Instruct', 'unsloth/Qwen3-VL-4B-Instruct', 'unsloth/gemma-4-E2B-it', 'unsloth/Qwen3-1.7B-unsloth-bnb-4bit', 'unsloth/Qwen3-8B-unsloth-bnb-4bit', 'unsloth/Qwen2.5-7B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3.5-0.8B', 'unsloth/Llama-3.2-3B-Instruct-unsloth-bnb-4bit', 'unsloth/gpt-oss-20b-BF16', 'unsloth/Llama-3.2-1B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen2.5-0.5B-unsloth-bnb-4bit', 'unsloth/Llama-3.2-1B', 'unsloth/Qwen3-4B-bnb-4bit', 'unsloth/Qwen3-4B-unsloth-bnb-4bit', 'unsloth/Qwen3-1.7B', 'unsloth/Qwen3.5-35B-A3B', 'unsloth/llama-3-8b-bnb-4bit', 'unsloth/Qwen2.5-Coder-7B-Instruct-bnb-4bit', 'unsloth/gemma-4-26B-A4B-it']"}
# {"timestamp": "2026-04-19T15:36:52.609194Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 514.12}
# {"timestamp": "2026-04-19T15:36:52.618165Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-04-19T15:36:52.618850Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-04-19T15:36:52.626280Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 13.86}
# {"timestamp": "2026-04-19T15:36:52.628030Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 15.45}
# {"timestamp": "2026-04-19T15:36:52.630026Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 17.23}
# {"timestamp": "2026-04-19T15:37:11.865882Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-gguf", "status_code": 200, "process_time_ms": 50.94}
# {"timestamp": "2026-04-19T15:37:11.877734Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/scan-folders", "status_code": 200, "process_time_ms": 8.34}
# {"timestamp": "2026-04-19T15:37:11.878449Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 9.0}
# {"timestamp": "2026-04-19T15:37:11.879173Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-models", "status_code": 200, "process_time_ms": 9.61}
# {"timestamp": "2026-04-19T15:37:11.880178Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/recommended-folders", "status_code": 200, "process_time_ms": 10.52}
# {"timestamp": "2026-04-19T15:37:58.099858Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 3.43}
# {"timestamp": "2026-04-19T15:37:58.106779Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/recommended-folders", "status_code": 200, "process_time_ms": 1.28}
# {"timestamp": "2026-04-19T15:37:58.125160Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/scan-folders", "status_code": 200, "process_time_ms": 1.57}
# {"timestamp": "2026-04-19T15:37:58.131767Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-models", "status_code": 200, "process_time_ms": 1.8}
# {"timestamp": "2026-04-19T15:37:58.137423Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-gguf", "status_code": 200, "process_time_ms": 3.66}
# {"timestamp": "2026-04-19T15:38:05.437372Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 271.08}
# {"timestamp": "2026-04-19T15:38:09.544625Z", "level": "info", "event": "Detected remote GGUF repo 'unsloth/gemma-4-E2B-it-GGUF', variant=UD-Q4_K_XL, vision=True"}
# {"timestamp": "2026-04-19T15:38:09.553714Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-04-19T15:38:09.562328Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/validate", "status_code": 200, "process_time_ms": 507.29}
# {"timestamp": "2026-04-19T15:38:09.566789Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 1.78}
# {"timestamp": "2026-04-19T15:38:10.457959Z", "level": "info", "event": "Detected remote GGUF repo 'unsloth/gemma-4-E2B-it-GGUF', variant=UD-Q4_K_XL, vision=True"}
# {"timestamp": "2026-04-19T15:38:10.948635Z", "level": "info", "event": "Resolving GGUF: unsloth/gemma-4-E2B-it-GGUF/gemma-4-E2B-it-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-04-19T15:38:11.033785Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 1.43}
# {"timestamp": "2026-04-19T15:38:11.181889Z", "level": "info", "event": "GGUF resolved from cache: /root/.cache/huggingface/hub/models--unsloth--gemma-4-E2B-it-GGUF/snapshots/f064409f340b34190993560b2168133e5dbae558/gemma-4-E2B-it-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-04-19T15:38:11.415380Z", "level": "info", "event": "Downloading mmproj: unsloth/gemma-4-E2B-it-GGUF/mmproj-BF16.gguf"}
# mmproj-BF16.gguf:   0%|          | 0.00/987M [00:00<?, ?B/s]
# {"timestamp": "2026-04-19T15:38:13.041860Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 1.2}
# {"timestamp": "2026-04-19T15:38:15.323076Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 26.42}
# {"timestamp": "2026-04-19T15:38:17.506063Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 1.17}
# {"timestamp": "2026-04-19T15:38:19.528207Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 1.59}
# {"timestamp": "2026-04-19T15:38:21.505799Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 1.35}
# {"timestamp": "2026-04-19T15:38:22.362289Z", "level": "info", "event": "GGUF metadata: context_length=131072"}
# {"timestamp": "2026-04-19T15:38:22.362997Z", "level": "info", "event": "GGUF metadata: chat_template=16317 chars"}
# {"timestamp": "2026-04-19T15:38:22.363600Z", "level": "info", "event": "GGUF metadata: model supports reasoning (enable_thinking)"}
# {"timestamp": "2026-04-19T15:38:22.365126Z", "level": "info", "event": "GGUF metadata: model supports tool calling"}
# {"timestamp": "2026-04-19T15:38:22.392577Z", "level": "info", "event": "GGUF size: 3.0 GB, est. KV cache: 2.0 GB, context: 131072, GPUs free: [(0, 14910)], selected: [0], fit: False"}
# {"timestamp": "2026-04-19T15:38:22.393149Z", "level": "info", "event": "Reasoning model: enable_thinking=True by default"}
# {"timestamp": "2026-04-19T15:38:22.394002Z", "level": "info", "event": "Using mmproj for vision: /root/.cache/huggingface/hub/models--unsloth--gemma-4-E2B-it-GGUF/snapshots/f064409f340b34190993560b2168133e5dbae558/mmproj-BF16.gguf"}
# {"timestamp": "2026-04-19T15:38:22.395191Z", "level": "info", "event": "Starting llama-server: /root/.unsloth/llama.cpp/llama-server -m /root/.cache/huggingface/hub/models--unsloth--gemma-4-E2B-it-GGUF/snapshots/f064409f340b34190993560b2168133e5dbae558/gemma-4-E2B-it-UD-Q4_K_XL.gguf --port 51403 -c 131072 --parallel 1 --flash-attn on --no-context-shift -ngl -1 --jinja --chat-template-kwargs {\"enable_thinking\": true} --mmproj /root/.cache/huggingface/hub/models--unsloth--gemma-4-E2B-it-GGUF/snapshots/f064409f340b34190993560b2168133e5dbae558/mmproj-BF16.gguf"}
# {"timestamp": "2026-04-19T15:38:23.510584Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 1.84}
# {"timestamp": "2026-04-19T15:38:25.508605Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 1.83}
# {"timestamp": "2026-04-19T15:38:27.525025Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 1.78}
# {"timestamp": "2026-04-19T15:38:29.527130Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 20.38}
# {"timestamp": "2026-04-19T15:38:29.983354Z", "level": "info", "event": "llama-server ready on port 51403 for model 'unsloth/gemma-4-E2B-it-GGUF'"}
# {"timestamp": "2026-04-19T15:38:29.984316Z", "level": "info", "event": "Loaded GGUF model via llama-server: unsloth/gemma-4-E2B-it-GGUF"}
# {"timestamp": "2026-04-19T15:38:30.041591Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-04-19T15:38:30.048414Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/load", "status_code": 200, "process_time_ms": 20095.34}
# {"timestamp": "2026-04-19T15:38:30.452690Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 8.7}
# {"timestamp": "2026-04-19T15:38:30.462938Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-04-19T15:38:30.469625Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 15.39}
# {"timestamp": "2026-04-19T15:38:30.476706Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-04-19T15:38:30.477764Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-04-19T15:38:30.479103Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 3.66}
# =

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
